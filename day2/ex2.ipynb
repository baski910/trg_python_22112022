# %%
# concat - concatenating dataframes

import pandas as pd

df1 = pd.read_csv('first.csv')
df2 = pd.read_csv('second.csv')

#print(df1)

#print(df2)

df3 = pd.concat([df1,df2])

df3.reset_index() # reset the index from 0 to number of rows

print(df3)
# Out:
#     id   first_name   last_name                   company_name  \
# 0    1      Aleshia  Tomkiewicz        Alan D Rosenburg Cpa Pc
# 1    2         Evan   Zigomalas             Cap Gemini America
# 2    3       France     Andrade            Elliott, John W Esq
# 3    4      Ulysses   Mcwalters                 Mcmahan, Ben L
# 4    5       Tyisha      Veness                 Champagne Room
# 5    6         Eric       Rampy        Thompson, Michael C Esq
# 6    7         Marg    Grasmick  Wrangle Hill Auto Auct & Slvg
# 7    8      Laquita       Hisaw          In Communications Inc
# 8    9         Lura    Manzella                Bizerba Usa Inc
# 9   10       Yuette      Klapec                      Max Video
# 0   11     Fernanda      Writer           K & R Associates Inc
# 1   12  Charlesetta         Erm               Cain, John M Esq
# 2   13     Corrinne       Jaret              Sound Vision Corp
# 3   14       Niesha       Bruch         Rowley/hansell Petetin
# ...
