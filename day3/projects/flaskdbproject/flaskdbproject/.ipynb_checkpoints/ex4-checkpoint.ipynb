# %%
# create file and directory struture
# app/
#   __init__.py
#  models.py
#  templates/
#
# config.py
# run.py

# contents of config.py
SECRET_KEY='thisisarandomgeneratedstring'
SQLALCHEMY_DATABASE_URI = "postgresql+psycopg2://sample_db_user_1:password@localhost:5432/sample_db_1"

# contents of run.py
from app import db,create_app

app = create_app()

if __name__ == '__main__':
    app.run()
    
# contents of app/__init__.py
# modules needed
# flask
# flask-sqlalchemy
# flask-migrate

# commands used for migrating
# flask db init  - migrations
# flask db migrate - migrations/version/*.py
# flask db upgrade - create tables inside database
import os
from flask import Flask, render_template, request, redirect, url_for
from flask_sqlalchemy import SQLAlchemy
from flask_migrate import Migrate


db = SQLAlchemy()

def create_app():
    from .models import Book
    app = Flask(__name__,instance_path= os.getcwd(),instance_relative_config=True)
    app.config.from_pyfile('config.py')
    db.init_app(app)
    migrate = Migrate(app,db)

    return app

# contents of models.py
from app import db

class Book(db.Model):
    __tablename__ = 'books'
    bookid =  db.Column(db.Integer,primary_key=True)
    booktitle = db.Column(db.String(50))
    bookauthor = db.Column(db.String(50))
